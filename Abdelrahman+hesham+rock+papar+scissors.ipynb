# %%
'''this awesome thing was created by THE AWESOME PRINCE 
just kidding anyways this is a Rock Papper Scissors game depends on if conditions that compare,
between the input of the user and a random input generated by the computer then both input are compared,
then the result is printed either it is a win for the player or a win for the computer or a draw / tie.'''

from random import randint as r 
x=r(0,2)
z=1
while z==1:
    y=int(input("hello there,wanna play a game of rock, paper, sissors? if rock enter 0 if paper enter 1 if sissors enter 2 = "))
    while True:
        if x==0 and y==0:
            print('p-rock vs com-rock ::draw')
        elif x==0 and y==1:
            print('p-rock vs com-siss ::you lost haha, i won GG')
        elif x==0 and y==2:
            print("p-rock vs com-papper ::you won, i lost don't get used to it")
        elif x==1 and y==0:
            print('p-paper vs com-rock ::you won, good job')
        elif x==1 and y==1:
            print('p-paper vs com-paper ::draw')
        elif x==1 and y==2:
            print('p-paper vs com-sissors ::i won, pitty human')
        elif x==2 and y==0:
            print('p-sissors vs com-rock ::i won, you dumn being')
        elif x==2 and y==1:
            print('p-sissors vs com-paper ::you won, but next time i will win')
        elif x==2 and y==2:
            print('p-sissors vs com-sissors ::draw')
        else:
            print('not valid play')
            continue
        break
    u=int(input("wanna play again if yes enter 1 or no enter 0"))
    if u==1:
        continue
    else:
        break
# Out:
# hello there,wanna play a game of rock, paper, sissors? if rock enter 0 if paper enter 1 if sissors enter 2 = 0
# p-paper vs com-rock ::you won, good job
# wanna play again if yes enter 1 or no enter 01
# hello there,wanna play a game of rock, paper, sissors? if rock enter 0 if paper enter 1 if sissors enter 2 = 2
# p-paper vs com-sissors ::i won, pitty human
# wanna play again if yes enter 1 or no enter 01
# hello there,wanna play a game of rock, paper, sissors? if rock enter 0 if paper enter 1 if sissors enter 2 = 1
# p-paper vs com-paper ::draw
# wanna play again if yes enter 1 or no enter 01
# hello there,wanna play a game of rock, paper, sissors? if rock enter 0 if paper enter 1 if sissors enter 2 = 2
# p-paper vs com-sissors ::i won, pitty human
# wanna play again if yes enter 1 or no enter 00
